# %%
import sys
import os

# Get absolute path to project root (one level above /notebooks)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Add project root to Python path
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print("Project root added:", project_root)
print("Python path now includes src?:", any("src" in p for p in sys.path))
# Out:
# Project root added: /Users/xaiair/Documents/asd-blood-rnaseq-ml
# Python path now includes src?: False
